# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cars_engage_2022_updated.csv")
df.head()
# Out:
#    S.no. Company      Model  Variant Ex-Showroom_Price Displacement Cylinders  \
# 0      0    Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc         2
# 1      1    Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc         2
# 2      2    Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc         2
# 3      3    Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc         2
# 4      4    Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc         2
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  ...  \
# 0                    2  RWD (Rear Wheel Drive)                In-line  ...
# 1                    2  RWD (Rear Wheel Drive)                In-line  ...
# 2                    2  RWD (Rear Wheel Drive)                In-line  ...
# 3                    2  RWD (Rear Wheel Drive)                In-line  ...
# 4                    2  RWD (Rear Wheel Drive)                In-line  ...
#
#   ABS_(Anti-lock_Braking_System) Adjustable_Headrests Gross_Vehicle_Weight  \
# 0                            Yes             All Rows              1370 kg
# 1                            Yes             All Rows              1370 kg
# 2                            Yes             All Rows              1370 kg
# 3                            Yes             All Rows              1370 kg
# 4                            Yes             All Rows              1370 kg
#
#                                              Airbags Door_Ajar_Warning  \
# 0  Front passenger frontal airbag, Driver frontal...               Yes
# 1  Front passenger frontal airbag, Driver frontal...               Yes
# 2  Front passenger frontal airbag, Driver frontal...               Yes
# 3  Front passenger frontal airbag, Driver frontal...               Yes
# 4  Front passenger frontal airbag, Driver frontal...               Yes
#
#   EBD_(Electronic_Brake-force_Distribution) Fasten_Seat_Belt_Warning  \
# 0                                       Yes                      Yes
# 1                                        No                      Yes
# 2                                        No                      Yes
# 3                                        No                      Yes
# 4                                        No                      Yes
#
#   Gear_Shift_Reminder        Parking_Assistance  Infotainment_Screen
# 0                 Yes  Rear sensors with camera      Touch Sensitive
# 1                 Yes  Rear sensors with camera      Touch Sensitive
# 2                 Yes  Rear sensors with camera      Touch Sensitive
# 3                 Yes  Rear sensors with camera      Touch Sensitive
# 4                 Yes  Rear sensors with camera      Touch Sensitive
#
# [5 rows x 78 columns]

# %%
from io import StringIO

# %%
def get_graph_cylinder():
    data = list(set(df.Cylinders))
    # print(data)
    for i in data:
        if i.isdecimal():
            pass
        else:
            data.remove(i)
    print(data)

    li = []
    content = list(df.Cylinders)
    for i in data:
        li.append(content.count(i))
    print(li)

    fig = plt.figure("")
    plt.barh(data,li,color="skyblue")
    plt.xlabel("No. of cylinder")
    plt.ylabel("No of car")

    for index, value in enumerate(li):
        plt.text(value, index, str(value))

    imgdata = StringIO()
    fig.savefig(imgdata, format='svg')
    imgdata.seek(0)

    fig = imgdata.getvalue()
    return fig

get_graph_cylinder()
# Out:
# ['10', '16', '2', '8', '3', '6', '5', '4', '12']
# [10, 4, 6, 54, 227, 109, 10, 832, 21]
# '<?xml version="1.0" encoding="utf-8" standalone="no"?>\n<!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"\n  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">\n<svg xmlns:xlink="http://www.w3.org/1999/xlink" width="432pt" height="288pt" viewBox="0 0 432 288" xmlns="http://www.w3.org/2000/svg" version="1.1">\n <metadata>\n  <rdf:RDF xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:cc="http://creativecommons.org/ns#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">\n   <cc:Work>\n    <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/>\n    <dc:date>2022-05-22T21:34:46.009102</dc:date>\n    <dc:format>image/svg+xml</dc:format>\n    <dc:creator>\n     <cc:Agent>\n      <dc:title>Matplotlib v3.5.2, https://matplotlib.org/</dc:title>\n     </cc:Agent>\n    </dc:creator>\n   </cc:Work>\n  </rdf:RDF>\n </metadata>\n <defs>\n  <style type="text/css">*{stroke-linejoin: round; stroke-linecap: butt}</style>\n </defs>\n <g id="figure_1">\n  <g id="patch_1">\n   <path d="M 0 288 \nL 432 288 \nL 432 0 \nL 0 0 \nL 0 288 \nz\n" style="fill: none"/>\n  </g>\n  <g id="axes_1">\n   <g id="patch_2">\n    <path d="M 54 252 \nL 388.8 252 \nL 388.8 34.56 \nL 54 34.56 \nz\n" style="fill: #ffffff"/>\n   </g>\n   <g id="patch_3">\n    <path d="M 54 242.116364 \nL 57.832418 242.116364 \nL 57.832418 224.146116 \nL 54 224.146116 \nz\n" clip-path="url(#pa830f5ea76)" style="fill: #87ceeb"/>\n   </g>\n   <g id="patch_4">\n    <path d="M 54 219.653554 \nL 55.532967 219.653554 \nL 55.532967 201.683306 \nL 54 201.683306 \nz\n" clip-path="url(#pa830f5ea76)" style="fill: #87ceeb"/>\n   </g>\n   <g id="patch_5">\n    <path d="M 54 197.190744 \nL 56.299451 197.190744 \nL 56.299451 179.220496 \nL 54 179.220496 \nz\n" clip-path="url(#pa830f5ea76)" style="fill: #87ceeb"/>\n   </g>\n   <g id="patch_6">\n    <path d="M 54 174.727934 \nL 74.695055 174.727934 \nL 74.695055 156.757686 \nL 54 156.757686 \nz\n" clip-path="url(#pa830f5ea76)" style="fill: #87ceeb"/>\n   </g>\n   <g id="patch_7">\n    <path d="M 54 152.265124 \nL 140.995879 152.265124 \nL 140.995879 134.294876 \nL 54 134.294876 \nz\n" clip-path="url(#pa830f5ea76)" style="fill: #87ceeb"/>\n   </g>\n   <g id="patch_8">\n    <path d="M 54 129.802314 \nL 95.773352 129.802314 \nL 95.773352 111.832066 \nL 54 111.832066 \nz\n" clip-path="url(#pa830f5ea76)" style="fill: #87ceeb"/>\n   </g>\n   <g id="patch_9">\n    <path d="M 54 107.339504 \nL 57.832418 107.339504 \nL 57.832418 89.369256 \nL 54 89.369256 \nz\n" clip-path="url(#pa830f5ea76)" style="fill: #87ceeb"/>\n   </g>\n   <g id="patch_10">\n    <path d="M 54 84.876694 \nL 372.857143 84.876694 \nL 372.857143 66.906446 \nL 54 66.906446 \nz\n" clip-path="url(#pa830f5ea76)" style="fill: #87ceeb"/>\n   </g>\n   <g id="patch_11">\n    <path d="M 54 62.413884 \nL 62.048077 62.413884 \nL 62.048077 44.443636 \nL 54 44.443636 \nz\n" clip-path="url(#pa830f5ea76)" style="fill: #87ceeb"/>\n   </g>\n   <g id="matplotlib.axis_1">\n    <g id="xtick_1">\n     <g id="line2d_1">\n      <defs>\n       <path id="mf5cfde1644" d="M 0 0 \nL 0 3.5 \n" style="stroke: #000000; stroke-width: 0.8"/>\n      </defs>\n      <g>\n       <use xlink:href="#mf5cfde1644" x="54" y="252" style="stroke: #000000; stroke-width: 0.8"/>\n      </g>\n     </g>\n     <g id="text_1">\n      <!-- 0 -->\n      <g transform="translate(50.81875 266.598437)scale(0.1 -0.1)">\n       <defs>\n        <path id="DejaVuSans-30" d="M 2034 4250 \nQ 1547 4250 1301 3770 \nQ 1056 3291 1056 2328 \nQ 1056 1369 1301 889 \nQ 1547 409 2034 409 \nQ 2525 409 2770 889 \nQ 3016 1369 3016 2328 \nQ 3016 3291 2770 3770 \nQ 2525 4250 2034 4250 \nz\nM 2034 4750 \nQ 2819 4750 3233 4129 \nQ 3647 3509 3647 2328 \nQ 3647 1150 3233 529 \nQ 2819 -91 2034 -91 \nQ 1250 -91 836 529 \nQ 422 1150 422 2328 \nQ 422 3509 836 4129 \nQ 1250 4750 2034 4750 \nz\n" transform="scale(0.015625)"/>\n       </defs>\n       <use xlink:href="#DejaVuSans-30"/>\n      </g>\n     </g>\n    </g>\n    <g id="xtick_2">\n     <g id="line2d_2">\n       ...

# %%
x = [1, 2, 3, 4, 5]

    y = [2, 5, 10, 17, 26]
    fig = plt.figure()
    plt.xlabel("x axis")

    plt.ylabel("y axis")

    plt.plot(x, y)

    # plt.show()

    imgdata = StringIO()
    fig.savefig(imgdata, format='svg')
    imgdata.seek(0)

    fig = imgdata.getvalue()
